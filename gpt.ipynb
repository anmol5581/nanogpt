# %%
import torch

print("PyTorch:", torch.__version__)
print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.11.0+cu128
# CUDA: True
# GPU: Tesla T4

# %%
# %cd /content
# !git clone https://github.com/anmol5581/nanogpt.git /content/nanogpt
# Out:
# fatal: destination path '/content/nanogpt' already exists and is not an empty directory.

# %%
# !git -C /content/nanogpt pull
# !python /content/nanogpt/train_gp2.py
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.12 KiB | 572.00 KiB/s, done.
# From https://github.com/anmol5581/nanogpt
#    1ba8abc..4810a08  main       -> origin/main
# Updating 1ba8abc..4810a08
# Fast-forward
#  gpt.ipynb    | 16 ++++++++--------
#  train_gp2.py | 43 ++++++++++++++++++++++++++++++++++++++++++-
#  2 files changed, 50 insertions(+), 9 deletions(-)
# ...
# Loading weights: 100% 148/148 [00:00<00:00, 5491.24it/s]
# Traceback (most recent call last):
#   File "/content/nanogpt/train_gp2.py", line 155, in <module>
#     idx = torch.cat((idx, idx_next), dim=1)
#                      ^^^
# NameError: name 'idx' is not defined. Did you mean: 'id'?

# %%
from transformers import GPT2LMHeadModel

sd_hf = GPT2LMHeadModel.from_pretrained("gpt2")

for name, param in sd_hf.named_parameters():
    print(name, param.shape)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# transformer.wte.weight torch.Size([50257, 768])
# transformer.wpe.weight torch.Size([1024, 768])
# transformer.h.0.ln_1.weight torch.Size([768])
# ...

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
set_seed(42)
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
